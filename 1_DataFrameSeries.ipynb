# %%
import pandas as pd

# %%
# load survey results as a dataframe
df = pd.read_csv("data/survey_results_public.csv")

df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
# shape of the dataframe
print(df.shape)
# Out:
# (88883, 85)

# %%
# set display options of pandas to display all columns!
pd.set_option("display.max_columns", 85)
pd.set_optison("display.max_rows", 85)

# %%
df.head(2)
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 0           1  I am a student who is learning to code      Yes
# 1           2  I am a student who is learning to code       No
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
#
#   UndergradMajor                                           EduOther OrgSize  \
# ...

# %%
# load schema.csv as a dataframe
schema_df = pd.read_csv("data/survey_results_schema.csv")

schema_df.head(2)
# Out:
#        Column                                       QuestionText
# 0  Respondent  Randomized respondent ID number (not in order ...
# 1  MainBranch  Which of the following options best describes ...

# %%
# show first 3 rows
df.head(3)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
# show last 3 rows
df.tail(3)
# Out:
#        Respondent MainBranch Hobbyist              OpenSourcer  \
# 88880       88802        NaN       No                    Never
# 88881       88816        NaN       No                    Never
# 88882       88863        NaN      Yes  Less than once per year
#
#                                               OpenSource  \
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
#                                               Employment Country  \
# 88880                                 Employed full-time     NaN
# 88881  Independent contractor, freelancer, or self-em...     NaN
# 88882             Not employed, and not looking for work   Spain
#
#               Student                             EdLevel  \
# 88880             NaN                                 NaN
# 88881             NaN                                 NaN
# ...

# %%
# columns property
print(type(df.columns))
print(df.columns)
# Out:
# <class 'pandas.core.indexes.base.Index'>
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
# ...

# %%
# Series containing counts of unique values
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# Access a group of rows and columns by label(s) or a boolean array
print("< Use 1 >")
print(df["Hobbyist"].loc[0])

print("\n< Use 2 >")
print(df.loc[0, "Hobbyist"])

print("\n< Use 3 >")
print(df.loc[[0, 5, 10, 17], "Hobbyist"])

print("\n< Use 4 >")
print(df.loc[5:10,'Hobbyist'])
# Out:
# < Use 1 >
# Yes
#
# < Use 2 >
# Yes
#
# < Use 3 >
# 0     Yes
# 5     Yes
# 10    Yes
# 17    Yes
# Name: Hobbyist, dtype: object
#
# < Use 4 >
# 5     Yes
# 6      No
# 7     Yes
# 8     Yes
# 9     Yes
# 10    Yes
# Name: Hobbyist, dtype: object

# %%
# iterate and display column names
for i in df.columns:
    print(i + ", ",end="")
# Out:
# Respondent, MainBranch, Hobbyist, OpenSourcer, OpenSource, Employment, Country, Student, EdLevel, UndergradMajor, EduOther, OrgSize, DevType, YearsCode, Age1stCode, YearsCodePro, CareerSat, JobSat, MgrIdiot, MgrMoney, MgrWant, JobSeek, LastHireDate, LastInt, FizzBuzz, JobFactors, ResumeUpdate, CurrencySymbol, CurrencyDesc, CompTotal, CompFreq, ConvertedComp, WorkWeekHrs, WorkPlan, WorkChallenge, WorkRemote, WorkLoc, ImpSyn, CodeRev, CodeRevHrs, UnitTests, PurchaseHow, PurchaseWhat, LanguageWorkedWith, LanguageDesireNextYear, DatabaseWorkedWith, DatabaseDesireNextYear, PlatformWorkedWith, PlatformDesireNextYear, WebFrameWorkedWith, WebFrameDesireNextYear, MiscTechWorkedWith, MiscTechDesireNextYear, DevEnviron, OpSys, Containers, BlockchainOrg, BlockchainIs, BetterLife, ITperson, OffOn, SocialMedia, Extraversion, ScreenName, SOVisit1st, SOVisitFreq, SOVisitTo, SOFindAnswer, SOTimeSaved, SOHowMuchTime, SOAccount, SOPartFreq, SOJobs, EntTeams, SOComm, WelcomeChange, SONewContent, Age, Ge
# ...

# %%
## slicing
# note that slicing is inclusive here!
df.loc[5:10, "Hobbyist":"Employment"]
# Out:
#    Hobbyist                 OpenSourcer  \
# 5       Yes                       Never
# 6        No                       Never
# 7       Yes     Less than once per year
# 8       Yes  Once a month or more often
# 9       Yes  Once a month or more often
# 10      Yes  Once a month or more often
#
#                                            OpenSource  \
# 5   The quality of OSS and closed source software ...
# 6   The quality of OSS and closed source software ...
# 7   OSS is, on average, of HIGHER quality than pro...
# 8   The quality of OSS and closed source software ...
# 9   OSS is, on average, of HIGHER quality than pro...
# 10  The quality of OSS and closed source software ...
#
#                                            Employment
# 5                                  Employed full-time
# 6   Independent contractor, freelancer, or self-em...
# 7                  Not employed, but looking for work
# 8                                  Employed full-time
# ...

# %% [markdown]
# # DataFrame and Series Basics - Selecting Rows and Columns

# %%
## gain better intuition of dataframes 

person = {"first": "Corey", "last": "Schafer", "email": "CoreyMSchafer@gmail.com"}

people = {"first": ["Corey"], "last": ["Schafer"], "email": ["CoreyMSchafer@gmail.com"]}

people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com"],
}

# %%
print(people["email"])
# Out:
# ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com']

# %%
## create dataframe from a dictionary
# keys -> names of the columns
# ith memebers of values -> contents of the rows
df = pd.DataFrame(people)

# %%
df.head()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
df.email
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
type(df["email"])
# Out:
# pandas.core.series.Series

# %%
# access two columns 
df[["last", "email"]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 1      Doe        JaneDoe@email.com
# 2      Doe        JohnDoe@email.com

# %%
type(df[['last','email']])
# Out:
# pandas.core.frame.DataFrame

# %%
# column names
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
# iloc: integer location (row)
df.iloc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
# access more rows with id
df.iloc[[0,2]]
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com

# %%
# access specific rows and column 
df.iloc[[0,2],[1,2]]
# Out:
#       last                    email
# 0  Schafer  CoreyMSchafer@gmail.com
# 2      Doe        JohnDoe@email.com

# %%
df.iloc[[0,2],["last","email"]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/c4/x03my2dj70s46m109bn58l2m0000gn/T/ipykernel_19307/3376545312.py in <module>
# ----> 1 df.iloc[[0,2],["last","email"]]
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
# Access a group of rows and columns by label(s) or a boolean array.
df.loc[0]
# Out:
# first                      Corey
# last                     Schafer
# email    CoreyMSchafer@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[0,1],'email']
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# Name: email, dtype: object

# %%
df.loc[[0,1],['email','last']]
# Out:
#                      email     last
# 0  CoreyMSchafer@gmail.com  Schafer
# 1        JaneDoe@email.com      Doe
