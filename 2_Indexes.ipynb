# %%
import pandas as pd

# %% [markdown]
# # Indexes - How to Set, Reset, and Use Indexes

# %%
# make dataset
people = {
    "first": ["Corey", "Jane", "John"],
    "last": ["Schafer", "Doe", "Doe"],
    "email": ["CoreyMSchafer@gmail.com", "JaneDoe@email.com", "JohnDoe@email.com"],
}

# construct dataframe from dataset
df = pd.DataFrame(people)

# display dataframe
df.head()
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df["email"]
# Out:
# 0    CoreyMSchafer@gmail.com
# 1          JaneDoe@email.com
# 2          JohnDoe@email.com
# Name: email, dtype: object

# %%
# Set the DataFrame index (row labels) using one or more existing columns
df.set_index("email")
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
# consider email address as the unique identifier of each row
df.set_index("email", inplace=True)

# %%
df.head()
# Out:
#                          first     last
# email
# CoreyMSchafer@gmail.com  Corey  Schafer
# JaneDoe@email.com         Jane      Doe
# JohnDoe@email.com         John      Doe

# %%
# Access a group of rows and columns by label
df.loc["CoreyMSchafer@gmail.com"]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
# locate a row
df.loc["CoreyMSchafer@gmail.com", "last"]
# Out:
# 'Schafer'

# %%
df.iloc[0]
# Out:
# first      Corey
# last     Schafer
# Name: CoreyMSchafer@gmail.com, dtype: object

# %%
# Reset the index of the DataFrame, and use the default one instead
df.reset_index(inplace=True)

df
# Out:
#    index                    email  first     last
# 0      0  CoreyMSchafer@gmail.com  Corey  Schafer
# 1      1        JaneDoe@email.com   Jane      Doe
# 2      2        JohnDoe@email.com   John      Doe

# %% [markdown]
# # Indexing on Stack-Overflow Dataset

# %%
# load datasets 
df = pd.read_csv("data/survey_results_public.csv", index_col="Respondent")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="Column")

# set viewing option of pandas to show all column
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head(2)
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.loc[10, "MgrIdiot"]
# Out:
# 'Somewhat confident'

# %%
# make search by label easy by using changing index column
schema_df.loc["MgrIdiot", "QuestionText"]
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
## sort based on column label/index 
# It will be alphabetical here because labels are strings
schema_df.sort_index(ascending=False, inplace=True)

schema_df.head(5)
# Out:
#                                                    QuestionText
# Column
# YearsCodePro  How many years have you coded professionally (...
# YearsCode     Including any education, how many years have y...
# WorkWeekHrs    On average, how many hours per week do you work?
# WorkRemote                      How often do you work remotely?
# WorkPlan                How structured or planned is your work?
